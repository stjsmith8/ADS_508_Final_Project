# %% [markdown]
# 05 — Model Training
# TalentIQ Technologies | ADS508 Data Science with Cloud Computing
# Authors: Ramin Fazli & Stephanie Smith
# GitHub: https://github.com/raminfazlirf/MLOps-for-Data-Science-ADS-508-02-
# Team Repo: https://github.com/stjsmith8/ADS_508_Final_Project
#
# Prepared data source: https://github.com/stjsmith8/ADS_508_Final_Project/tree/main/data/processed

# %%
import boto3
import sagemaker
import pandas as pd
import numpy as np

from sagemaker import image_uris
from sagemaker.inputs import TrainingInput
from sagemaker.estimator import Estimator
from sagemaker.tuner import HyperparameterTuner, IntegerParameter, ContinuousParameter

session = sagemaker.Session()
role = sagemaker.get_execution_role()
region = session.boto_region_name
bucket = "ads508-team-4-private"

print("Region:", region)
print("Role:", role)
# Out:
# sagemaker.config INFO - Not applying SDK defaults from location: /etc/xdg/sagemaker/config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: /home/sagemaker-user/.config/sagemaker/config.yaml
# Region: us-east-1
# Role: arn:aws:iam::802896854792:role/LabRole

# %%
# load datasets from S3 bucket
train_path = f"s3://{bucket}/processed/train_attrition_smote.csv"
val_path   = f"s3://{bucket}/processed/validation_attrition_data.csv"
test_path  = f"s3://{bucket}/processed/test_attrition_data.csv"

train_df = pd.read_csv(train_path)
val_df   = pd.read_csv(val_path)
test_df  = pd.read_csv(test_path)

print("Train shape:", train_df.shape)
print("Validation shape:", val_df.shape)
print("Test shape:", test_df.shape)

print(train_df.head())
# Out:
# Train shape: (14778, 28)
# Validation shape: (1147, 28)
# Test shape: (1147, 28)
#    Age  DistanceFromHome  JobInvolvement  JobLevel  JobSatisfaction  \
# 0   54                16               1         3                3
# 1   20                21               3         3                2
# 2   30                 8               2         1                4
# 3   33                 7               3         2                1
# 4   40                11               3         2                1
#
#    EnvironmentSatisfaction  RelationshipSatisfaction  WorkLifeBalance  \
# 0                        3                         3                4
# 1                        1                         3                3
# 2                        3                         3                2
# 3                        4                         1                3
# 4                        1                         1                4
#
#    MonthlyIncome  NumCompaniesWorked  ...    salary_gap  OverTime_Yes  \
# 0          12480                   4  ...  56567.728947             0
# 1          15402                   1  ...  53645.728947             0
# 2           2180                   6  ...  59665.109845             0
# 3           4373                   0  ...  87310.754386             0
# 4          12441                   4  ...  90556.714045             0
#
#    MaritalStatus_Single  MaritalStatus_Married  IncomeCategory_Medium  \
# 0                     0                      0                      1
# 1                     1                      0                      0
# 2                     0                      0                      0
# 3                     0                      1                      0
# 4                     1                      0                      1
#
#    IncomeCategory_High  TenureCategory_3-5 years  TenureCategory_6-10 years  \
# 0                    0                         0                          1
# 1                    1                         0                          0
# 2                    0                         1                          0
# 3                    0                         1                          0
# 4                    0                         0                          0
#
#    TenureCategory_10+ years  Attrition
# 0                         0          1
# 1                         1          1
# 2                         0          1
# 3                         0          0
# 4                         1          0
#
# [5 rows x 28 columns]

# %%
# ensure we only keep wanted features
selected_features = [
    "Age",
    "DistanceFromHome",
    "JobInvolvement",
    "JobLevel",
    "JobSatisfaction",
    "EnvironmentSatisfaction",
    "RelationshipSatisfaction",
    "WorkLifeBalance",
    "MonthlyIncome",
    "NumCompaniesWorked",
    "YearsAtCompany",
    "YearsInCurrentRole",
    "YearsSinceLastPromotion",
    "NoRecentPromotion",
    "StagnationScore",
    "SatisfactionIndex",
    "external_avg_salary",
    "external_job_demand",
    "salary_gap",
    "OverTime_Yes",
    "MaritalStatus_Single",
    "MaritalStatus_Married",
    "IncomeCategory_Medium",
    "IncomeCategory_High",
    "TenureCategory_3-5 years",
    "TenureCategory_6-10 years",
    "TenureCategory_10+ years",
]

selected_features = [c for c in selected_features if c in train_df.columns]

target_col = "Attrition"

train_df = train_df[[target_col] + selected_features]
val_df   = val_df[[target_col] + selected_features]
test_df  = test_df[[target_col] + selected_features]

print("Final feature count:", len(selected_features))
print("Training columns:", train_df.columns.tolist())
# Out:
# Final feature count: 27
# Training columns: ['Attrition', 'Age', 'DistanceFromHome', 'JobInvolvement', 'JobLevel', 'JobSatisfaction', 'EnvironmentSatisfaction', 'RelationshipSatisfaction', 'WorkLifeBalance', 'MonthlyIncome', 'NumCompaniesWorked', 'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion', 'NoRecentPromotion', 'StagnationScore', 'SatisfactionIndex', 'external_avg_salary', 'external_job_demand', 'salary_gap', 'OverTime_Yes', 'MaritalStatus_Single', 'MaritalStatus_Married', 'IncomeCategory_Medium', 'IncomeCategory_High', 'TenureCategory_3-5 years', 'TenureCategory_6-10 years', 'TenureCategory_10+ years']

# %%
# update format so we can use Sagemaker built in XGboost
train_xgb_local = "/tmp/train_xgb.csv"
val_xgb_local   = "/tmp/validation_xgb.csv"
test_xgb_local  = "/tmp/test_xgb.csv"

train_df.to_csv(train_xgb_local, index=False, header=False)
val_df.to_csv(val_xgb_local, index=False, header=False)
test_df.to_csv(test_xgb_local, index=False, header=False)

print("Saved local built-in XGBoost files.")
# Out:
# Saved local built-in XGBoost files.

# %%
#upload to S3
train_xgb_s3 = f"s3://{bucket}/processed_builtin/train/train_xgb.csv"
val_xgb_s3   = f"s3://{bucket}/processed_builtin/validation/validation_xgb.csv"
test_xgb_s3  = f"s3://{bucket}/processed_builtin/test/test_xgb.csv"

session.upload_data(train_xgb_local, bucket=bucket, key_prefix="processed_builtin/train")
session.upload_data(val_xgb_local, bucket=bucket, key_prefix="processed_builtin/validation")
session.upload_data(test_xgb_local, bucket=bucket, key_prefix="processed_builtin/test")

print(train_xgb_s3)
print(val_xgb_s3)
print(test_xgb_s3)
# Out:
# s3://ads508-team-4-private/processed_builtin/train/train_xgb.csv
# s3://ads508-team-4-private/processed_builtin/validation/validation_xgb.csv
# s3://ads508-team-4-private/processed_builtin/test/test_xgb.csv

# %%
# get built in xgboost container
xgb_image = image_uris.retrieve(
    framework="xgboost",
    region=region,
    version="1.7-1"
)

print("XGBoost image:", xgb_image)
# Out:
# XGBoost image: 683313688378.dkr.ecr.us-east-1.amazonaws.com/sagemaker-xgboost:1.7-1

# %%
# create Sagemaker training job
xgb_estimator = Estimator(
    image_uri=xgb_image,
    role=role,
    instance_count=1,
    instance_type="ml.m5.xlarge",
    output_path=f"s3://{bucket}/model-artifacts/",
    sagemaker_session=session
)

xgb_estimator.set_hyperparameters(
    objective="binary:logistic",
    eval_metric="auc",
    num_round=300,
    max_depth=4,
    eta=0.05,
    subsample=0.8,
    colsample_bytree=0.8,
    min_child_weight=3,
    gamma=0.05,
    alpha=0.1,
    **{"lambda": 1.0}
)

train_input = TrainingInput(
    s3_data=f"s3://{bucket}/processed_builtin/train/",
    content_type="text/csv"
)

validation_input = TrainingInput(
    s3_data=f"s3://{bucket}/processed_builtin/validation/",
    content_type="text/csv"
)

xgb_estimator.fit({
    "train": train_input,
    "validation": validation_input
})
# Out:
# INFO:sagemaker.telemetry.telemetry_logging:SageMaker Python SDK will collect telemetry to help us better understand our user's needs, diagnose issues, and deliver additional features.
# To opt out of telemetry, please disable via TelemetryOptOut parameter in SDK defaults config. For more information, refer to https://sagemaker.readthedocs.io/en/stable/overview.html#configuring-and-using-defaults-with-the-sagemaker-python-sdk.
# INFO:sagemaker:Creating training-job with name: sagemaker-xgboost-2026-04-11-19-43-17-420
# 2026-04-11 19:43:18 Starting - Starting the training job...
# 2026-04-11 19:43:32 Starting - Preparing the instances for training...
# 2026-04-11 19:44:20 Downloading - Downloading the training image......
# 2026-04-11 19:45:11 Training - Training image download completed. Training in progress../miniconda3/lib/python3.9/site-packages/sagemaker_containers/_server.py:22: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# [2026-04-11 19:45:21.711 ip-10-0-226-173.ec2.internal:7 INFO utils.py:28] RULE_JOB_STOP_SIGNAL_FILENAME: None
# [2026-04-11 19:45:21.782 ip-10-0-226-173.ec2.internal:7 INFO profiler_config_parser.py:111] User has disabled profiler.
# [2026-04-11:19:45:22:INFO] Imported framework sagemaker_xgboost_container.training
# [2026-04-11:19:45:22:INFO] Failed to parse hyperparameter eval_metric value auc to Json.
# Returning the value itself
# [2026-04-11:19:45:22:INFO] Failed to parse hyperparameter objective value binary:logistic to Json.
# Returning the value itself
# [2026-04-11:19:45:22:INFO] No GPUs detected (normal if no gpus installed)
# [2026-04-11:19:45:22:INFO] Running XGBoost Sagemaker in algorithm mode
# [2026-04-11:19:45:22:INFO] Determined 0 GPU(s) available on the instance.
# [2026-04-11:19:45:22:INFO] Determined delimiter of CSV input is ','
# [2026-04-11:19:45:22:INFO] Determined delimiter of CSV input is ','
# [2026-04-11:19:45:22:INFO] File path /opt/ml/input/data/train of input files
# [2026-04-11:19:45:22:INFO] Making smlinks from folder /opt/ml/input/data/train to folder /tmp/sagemaker_xgboost_input_data
# [2026-04-11:19:45:22:INFO] creating symlink between Path /opt/ml/input/data/train/train_xgb.csv and destination /tmp/sagemaker_xgboost_input_data/train_xgb.csv-2160873269724175140
# [2026-04-11:19:45:22:INFO] files path: /tmp/sagemaker_xgboost_input_data
# [2026-04-11:19:45:22:INFO] Determined delimiter of CSV input is ','
# [2026-04-11:19:45:22:INFO] File path /opt/ml/input/data/validation of input files
# [2026-04-11:19:45:22:INFO] Making smlinks from folder /opt/ml/input/data/validation to folder /tmp/sagemaker_xgboost_input_data
# [2026-04-11:19:45:22:INFO] creating symlink between Path /opt/ml/input/data/validation/validation_xgb.csv and destination /tmp/sagemaker_xgboost_input_data/validation_xgb.csv-6196425787318399624
# [2026-04-11:19:45:22:INFO] files path: /tmp/sagemaker_xgboost_input_data
# [2026-04-11:19:45:22:INFO] Determined delimiter of CSV input is ','
# [2026-04-11:19:45:22:INFO] Single node training.
# [2026-04-11:19:45:22:INFO] Train matrix has 14778 rows and 27 columns
# [2026-04-11:19:45:22:INFO] Validation matrix has 1147 rows
# [2026-04-11 19:45:22.170 ip-10-0-226-173.ec2.internal:7 INFO json_config.py:92] Creating hook from json_config at /opt/ml/input/config/debughookconfig.json.
# [2026-04-11 19:45:22.171 ip-10-0-226-173.ec2.internal:7 INFO hook.py:206] tensorboard_dir has not been set for the hook. SMDebug will not be exporting tensorboard summaries.
# [2026-04-11 19:45:22.171 ip-10-0-226-173.ec2.internal:7 INFO hook.py:259] Saving to /opt/ml/output/tensors
# [2026-04-11 19:45:22.172 ip-10-0-226-173.ec2.internal:7 INFO state_store.py:77] The checkpoint config file /opt/ml/input/config/checkpointconfig.json does not exist.
# [2026-04-11:19:45:22:INFO] Debug hook created from config
# [0]#011train-auc:0.74751#011validation-auc:0.50101
# [2026-04-11 19:45:22.223 ip-10-0-226-173.ec2.internal:7 INFO hook.py:427] Monitoring the collections: metrics
# [2026-04-11 19:45:22.226 ip-10-0-226-173.ec2.internal:7 INFO hook.py:491] Hook is writing from the hook with pid: 7
# [1]#011train-auc:0.79566#011validation-auc:0.50529
# [2]#011train-auc:0.80494#011validation-auc:0.51239
# [3]#011train-auc:0.80113#011validation-auc:0.51618
# [4]#011train-auc:0.81089#011validation-auc:0.50560
# [5]#011train-auc:0.81060#011validation-auc:0.50306
# [6]#011train-auc:0.81624#011validation-auc:0.50435
# [7]#011train-auc:0.81628#011validation-auc:0.50193
# [8]#011train-auc:0.82002#011validation-auc:0.50578
# [9]#011train-auc:0.82508#011validation-auc:0.50386
# [10]#011train-auc:0.82732#011validation-auc:0.50214
# [11]#011train-auc:0.83719#011validation-auc:0.50708
# [12]#011train-auc:0.83707#011validation-auc:0.50473
# [13]#011train-auc:0.83562#011validation-auc:0.50462
# [14]#011train-auc:0.83788#011validation-auc:0.50323
# [15]#011train-auc:0.84509#011validation-auc:0.50431
# [16]#011train-auc:0.85010#011validation-auc:0.50558
# [17]#011train-auc:0.85627#011validation-auc:0.50451
# [18]#011train-auc:0.85655#011validation-auc:0.50767
# [19]#011train-auc:0.85601#011validation-auc:0.50634
# [20]#011train-auc:0.85805#011validation-auc:0.51042
# [21]#011train-auc:0.85802#011validation-auc:0.51103
# [22]#011train-auc:0.85938#011validation-auc:0.51072
# [23]#011train-auc:0.86121#011validation-auc:0.51157
# [24]#011train-auc:0.86203#011validation-auc:0.51348
# [25]#011train-auc:0.86371#011validation-auc:0.51170
# [26]#011train-auc:0.86504#011validation-auc:0.51065
# [27]#011train-auc:0.86573#011validation-auc:0.51250
# [28]#011train-auc:0.86654#011validation-auc:0.51232
# [29]#011train-auc:0.86620#011validation-auc:0.51155
# [30]#011train-auc:0.86904#011validation-auc:0.51012
# [31]#011train-auc:0.87038#011validation-auc:0.51065
# [32]#011train-auc:0.87113#011validation-auc:0.50989
# [33]#011train-auc:0.87172#011validation-auc:0.50782
# [34]#011train-auc:0.87358#011validation-auc:0.50949
# [35]#011train-auc:0.87426#011validation-auc:0.51120
# [36]#011train-auc:0.87471#011validation-auc:0.51109
# [37]#011train-auc:0.87491#011validation-auc:0.51185
# [38]#011train-auc:0.87615#011validation-auc:0.51156
# [39]#011train-auc:0.87679#011validation-auc:0.51196
# [40]#011train-auc:0.87698#011validation-auc:0.51209
# [41]#011train-auc:0.87811#011validation-auc:0.51246
# [42]#011train-auc:0.87904#011validation-auc:0.51301
# [43]#011train-auc:0.87935#011validation-auc:0.51307
# [44]#011train-auc:0.87948#011validation-auc:0.51343
# [45]#011train-auc:0.87988#011validation-auc:0.51378
# [46]#011train-auc:0.88024#011validation-auc:0.51481
# [47]#011train-auc:0.88152#011validation-auc:0.51382
# [48]#011train-auc:0.88181#011validation-auc:0.51493
# [49]#011train-auc:0.88274#011validation-auc:0.51341
# [50]#011train-auc:0.88299#011validation-auc:0.51378
# [51]#011train-auc:0.88335#011validation-auc:0.51445
# [52]#011train-auc:0.88426#011validation-auc:0.51453
# [53]#011train-auc:0.88475#011validation-auc:0.51600
# [54]#011train-auc:0.88538#011validation-auc:0.51587
# [55]#011train-auc:0.88606#011validation-auc:0.51514
# [56]#011train-auc:0.88613#011validation-auc:0.51533
# [57]#011train-auc:0.88653#011validation-auc:0.51619
# [58]#011train-auc:0.88710#011validation-auc:0.51600
# [59]#011train-auc:0.88769#011validation-auc:0.51450
# [60]#011train-auc:0.88784#011validation-auc:0.51459
# [61]#011train-auc:0.88825#011validation-auc:0.51385
# [62]#011train-auc:0.88897#011validation-auc:0.51419
# [63]#011train-auc:0.88942#011validation-auc:0.51444
# [64]#011train-auc:0.88979#011validation-auc:0.51393
# [65]#011train-auc:0.89027#011validation-auc:0.51379
# [66]#011train-auc:0.89063#011validation-auc:0.51328
# [67]#011train-auc:0.89123#011validation-auc:0.51359
# [68]#011train-auc:0.89158#011validation-auc:0.51283
# [69]#011train-auc:0.89183#011validation-auc:0.51207
# [70]#011train-auc:0.89213#011validation-auc:0.51196
# [71]#011train-auc:0.89249#011validation-auc:0.51320
# [72]#011train-auc:0.89271#011validation-auc:0.51247
# [73]#011train-auc:0.89289#011validation-auc:0.51343
# [74]#011train-auc:0.89308#011validation-auc:0.51348
# [75]#011train-auc:0.89325#011validation-auc:0.51372
# [76]#011train-auc:0.89354#011validation-auc:0.51311
# [77]#011train-auc:0.89371#011validation-auc:0.51329
# [78]#011train-auc:0.89415#011validation-auc:0.51364
# [79]#011train-auc:0.89458#011validation-auc:0.51395
# [80]#011train-auc:0.89512#011validation-auc:0.51389
# [81]#011train-auc:0.89540#011validation-auc:0.51461
# [82]#011train-auc:0.89578#011validation-auc:0.51479
# [83]#011train-auc:0.89637#011validation-auc:0.51644
# [84]#011train-auc:0.89661#011validation-auc:0.51587
# [85]#011train-auc:0.89693#011validation-auc:0.51530
# [86]#011train-auc:0.89754#011validation-auc:0.51617
# [87]#011train-auc:0.89766#011validation-auc:0.51555
# [88]#011train-auc:0.89803#011validation-auc:0.51524
# [89]#011train-auc:0.89831#011validation-auc:0.51551
# [90]#011train-auc:0.89866#011validation-auc:0.51567
# [91]#011train-auc:0.89906#011validation-auc:0.51656
# [92]#011train-auc:0.89953#011validation-auc:0.51661
# [93]#011train-auc:0.89989#011validation-auc:0.51692
# [94]#011train-auc:0.90006#011validation-auc:0.51713
# [95]#011train-auc:0.90041#011validation-auc:0.51764
# [96]#011train-auc:0.90072#011validation-auc:0.51775
# [97]#011train-auc:0.90107#011validation-auc:0.51882
# [98]#011train-auc:0.90131#011validation-auc:0.51967
# [99]#011train-auc:0.90155#011validation-auc:0.51881
# [100]#011train-auc:0.90170#011validation-auc:0.51866
# [101]#011train-auc:0.90201#011validation-auc:0.51936
# [102]#011train-auc:0.90233#011validation-auc:0.51966
# [103]#011train-auc:0.90270#011validation-auc:0.52060
# [104]#011train-auc:0.90293#011validation-auc:0.52061
# [105]#011train-auc:0.90324#011validation-auc:0.52076
# [106]#011train-auc:0.90340#011validation-auc:0.52071
# [107]#011train-auc:0.90356#011validation-auc:0.52078
# [108]#011train-auc:0.90384#011validation-auc:0.52074
# [109]#011train-auc:0.90412#011validation-auc:0.52136
# [110]#011train-auc:0.90422#011validation-auc:0.52043
# [111]#011train-auc:0.90449#011validation-auc:0.52086
# [112]#011train-auc:0.90468#011validation-auc:0.52088
# [113]#011train-auc:0.90494#011validation-auc:0.52035
# [114]#011train-auc:0.90521#011validation-auc:0.52087
# [115]#011train-auc:0.90543#011validation-auc:0.52157
# [116]#011train-auc:0.90571#011validation-auc:0.52047
# [117]#011train-auc:0.90592#011validation-auc:0.52022
# [118]#011train-auc:0.90613#011validation-auc:0.52013
# [119]#011train-auc:0.90632#011validation-auc:0.52002
# [120]#011train-auc:0.90653#011validation-auc:0.51995
# [121]#011train-auc:0.90671#011validation-auc:0.51957
# [122]#011train-auc:0.90692#011validation-auc:0.52002
# [123]#011train-auc:0.90723#011validation-auc:0.51955
# [124]#011train-auc:0.90735#011validation-auc:0.51922
# [125]#011train-auc:0.90760#011validation-auc:0.51917
# [126]#011train-auc:0.90780#011validation-auc:0.51929
# [127]#011train-auc:0.90798#011validation-auc:0.51931
# [128]#011train-auc:0.90814#011validation-auc:0.51963
# [129]#011train-auc:0.90829#011validation-auc:0.51866
# [130]#011train-auc:0.90840#011validation-auc:0.51905
# [131]#011train-auc:0.90851#011validation-auc:0.51855
# [132]#011train-auc:0.90862#011validation-auc:0.51896
# [133]#011train-auc:0.90884#011validation-auc:0.51850
# [134]#011train-auc:0.90904#011validation-auc:0.51886
# [135]#011train-auc:0.90919#011validation-auc:0.51836
# [136]#011train-auc:0.90933#011validation-auc:0.51790
# [137]#011train-auc:0.90954#011validation-auc:0.51835
# [138]#011train-auc:0.90977#011validation-auc:0.51726
# [139]#011train-auc:0.91002#011validation-auc:0.51747
# [140]#011train-auc:0.91012#011validation-auc:0.51751
# [141]#011train-auc:0.91014#011validation-auc:0.51696
# [142]#011train-auc:0.91023#011validation-auc:0.51744
# [143]#011train-auc:0.91050#011validation-auc:0.51762
# [144]#011train-auc:0.91067#011validation-auc:0.51770
# [145]#011train-auc:0.91078#011validation-auc:0.51775
# [146]#011train-auc:0.91090#011validation-auc:0.51806
# [147]#011train-auc:0.91110#011validation-auc:0.51750
# [148]#011train-auc:0.91120#011validation-auc:0.51760
# [149]#011train-auc:0.91141#011validation-auc:0.51700
# [150]#011train-auc:0.91163#011validation-auc:0.51635
# [151]#011train-auc:0.91178#011validation-auc:0.51629
# [152]#011train-auc:0.91196#011validation-auc:0.51629
# [153]#011train-auc:0.91209#011validation-auc:0.51628
# [154]#011train-auc:0.91219#011validation-auc:0.51667
# [155]#011train-auc:0.91225#011validation-auc:0.51663
# [156]#011train-auc:0.91248#011validation-auc:0.51626
# [157]#011train-auc:0.91261#011validation-auc:0.51681
# [158]#011train-auc:0.91280#011validation-auc:0.51617
# [159]#011train-auc:0.91306#011validation-auc:0.51554
# [160]#011train-auc:0.91326#011validation-auc:0.51536
# [161]#011train-auc:0.91342#011validation-auc:0.51507
# [162]#011train-auc:0.91365#011validation-auc:0.51583
# [163]#011train-auc:0.91395#011validation-auc:0.51621
# [164]#011train-auc:0.91419#011validation-auc:0.51650
# [165]#011train-auc:0.91441#011validation-auc:0.51665
# [166]#011train-auc:0.91455#011validation-auc:0.51653
# [167]#011train-auc:0.91471#011validation-auc:0.51660
# [168]#011train-auc:0.91488#011validation-auc:0.51703
# [169]#011train-auc:0.91497#011validation-auc:0.51741
# [170]#011train-auc:0.91512#011validation-auc:0.51747
# [171]#011train-auc:0.91536#011validation-auc:0.51677
# [172]#011train-auc:0.91559#011validation-auc:0.51674
# [173]#011train-auc:0.91572#011validation-auc:0.51644
# [174]#011train-auc:0.91592#011validation-auc:0.51564
# [175]#011train-auc:0.91601#011validation-auc:0.51584
# [176]#011train-auc:0.91611#011validation-auc:0.51583
# [177]#011train-auc:0.91626#011validation-auc:0.51555
# [178]#011train-auc:0.91639#011validation-auc:0.51498
# [179]#011train-auc:0.91660#011validation-auc:0.51437
# [180]#011train-auc:0.91674#011validation-auc:0.51466
# [181]#011train-auc:0.91689#011validation-auc:0.51522
# [182]#011train-auc:0.91701#011validation-auc:0.51491
# [183]#011train-auc:0.91726#011validation-auc:0.51511
# [184]#011train-auc:0.91745#011validation-auc:0.51490
# [185]#011train-auc:0.91763#011validation-auc:0.51402
# [186]#011train-auc:0.91767#011validation-auc:0.51348
# [187]#011train-auc:0.91792#011validation-auc:0.51312
# [188]#011train-auc:0.91798#011validation-auc:0.51394
# [189]#011train-auc:0.91818#011validation-auc:0.51418
# [190]#011train-auc:0.91839#011validation-auc:0.51394
# [191]#011train-auc:0.91854#011validation-auc:0.51340
# [192]#011train-auc:0.91888#011validation-auc:0.51359
# [193]#011train-auc:0.91900#011validation-auc:0.51357
# [194]#011train-auc:0.91917#011validation-auc:0.51405
# [195]#011train-auc:0.91932#011validation-auc:0.51404
# [196]#011train-auc:0.91947#011validation-auc:0.51397
# [197]#011train-auc:0.91956#011validation-auc:0.51408
# [198]#011train-auc:0.91972#011validation-auc:0.51435
# [199]#011train-auc:0.91986#011validation-auc:0.51429
# [200]#011train-auc:0.92003#011validation-auc:0.51477
# [201]#011train-auc:0.92013#011validation-auc:0.51456
# [202]#011train-auc:0.92033#011validation-auc:0.51447
# [203]#011train-auc:0.92046#011validation-auc:0.51404
# [204]#011train-auc:0.92069#011validation-auc:0.51387
# [205]#011train-auc:0.92080#011validation-auc:0.51373
# [206]#011train-auc:0.92096#011validation-auc:0.51368
# [207]#011train-auc:0.92110#011validation-auc:0.51380
# [208]#011train-auc:0.92120#011validation-auc:0.51379
# [209]#011train-auc:0.92139#011validation-auc:0.51412
# [210]#011train-auc:0.92145#011validation-auc:0.51429
# [211]#011train-auc:0.92169#011validation-auc:0.51407
# [212]#011train-auc:0.92184#011validation-auc:0.51420
# [213]#011train-auc:0.92201#011validation-auc:0.51431
# [214]#011train-auc:0.92212#011validation-auc:0.51479
# [215]#011train-auc:0.92222#011validation-auc:0.51498
# [216]#011train-auc:0.92238#011validation-auc:0.51500
# [217]#011train-auc:0.92247#011validation-auc:0.51418
# [218]#011train-auc:0.92254#011validation-auc:0.51421
# [219]#011train-auc:0.92268#011validation-auc:0.51400
# [220]#011train-auc:0.92275#011validation-auc:0.51374
# [221]#011train-auc:0.92284#011validation-auc:0.51363
# [222]#011train-auc:0.92303#011validation-auc:0.51354
# [223]#011train-auc:0.92321#011validation-auc:0.51289
# [224]#011train-auc:0.92334#011validation-auc:0.51272
# [225]#011train-auc:0.92349#011validation-auc:0.51182
# [226]#011train-auc:0.92366#011validation-auc:0.51180
# [227]#011train-auc:0.92383#011validation-auc:0.51195
# [228]#011train-auc:0.92405#011validation-auc:0.51121
# [229]#011train-auc:0.92425#011validation-auc:0.51149
# [230]#011train-auc:0.92443#011validation-auc:0.51170
# [231]#011train-auc:0.92451#011validation-auc:0.51126
# [232]#011train-auc:0.92464#011validation-auc:0.51096
# [233]#011train-auc:0.92472#011validation-auc:0.51124
# [234]#011train-auc:0.92492#011validation-auc:0.51081
# [235]#011train-auc:0.92508#011validation-auc:0.51137
# [236]#011train-auc:0.92531#011validation-auc:0.51105
# [237]#011train-auc:0.92551#011validation-auc:0.51110
# [238]#011train-auc:0.92569#011validation-auc:0.51058
# [239]#011train-auc:0.92585#011validation-auc:0.51017
# [240]#011train-auc:0.92592#011validation-auc:0.51000
# [241]#011train-auc:0.92610#011validation-auc:0.50990
# [242]#011train-auc:0.92623#011validation-auc:0.50971
# [243]#011train-auc:0.92637#011validation-auc:0.50973
# [244]#011train-auc:0.92652#011validation-auc:0.50996
# [245]#011train-auc:0.92672#011validation-auc:0.51016
# [246]#011train-auc:0.92681#011validation-auc:0.51040
# [247]#011train-auc:0.92698#011validation-auc:0.51029
# [248]#011train-auc:0.92714#011validation-auc:0.51038
# [249]#011train-auc:0.92729#011validation-auc:0.51006
# [250]#011train-auc:0.92746#011validation-auc:0.51089
# [251]#011train-auc:0.92759#011validation-auc:0.51079
# [252]#011train-auc:0.92766#011validation-auc:0.51078
# [253]#011train-auc:0.92784#011validation-auc:0.51064
# [254]#011train-auc:0.92796#011validation-auc:0.51008
# [255]#011train-auc:0.92807#011validation-auc:0.51010
# [256]#011train-auc:0.92824#011validation-auc:0.51032
# [257]#011train-auc:0.92839#011validation-auc:0.51029
# [258]#011train-auc:0.92864#011validation-auc:0.51071
# [259]#011train-auc:0.92880#011validation-auc:0.51062
# [260]#011train-auc:0.92898#011validation-auc:0.51051
# [261]#011train-auc:0.92923#011validation-auc:0.51127
# [262]#011train-auc:0.92935#011validation-auc:0.51135
# [263]#011train-auc:0.92945#011validation-auc:0.51162
# [264]#011train-auc:0.92946#011validation-auc:0.51170
# [265]#011train-auc:0.92967#011validation-auc:0.51176
# [266]#011train-auc:0.92979#011validation-auc:0.51181
# [267]#011train-auc:0.92991#011validation-auc:0.51182
# [268]#011train-auc:0.93007#011validation-auc:0.51130
# [269]#011train-auc:0.93020#011validation-auc:0.51072
# [270]#011train-auc:0.93025#011validation-auc:0.51065
# [271]#011train-auc:0.93036#011validation-auc:0.51064
# [272]#011train-auc:0.93056#011validation-auc:0.51054
# [273]#011train-auc:0.93066#011validation-auc:0.51059
# [274]#011train-auc:0.93078#011validation-auc:0.51116
# [275]#011train-auc:0.93099#011validation-auc:0.51066
# [276]#011train-auc:0.93109#011validation-auc:0.51071
# [277]#011train-auc:0.93125#011validation-auc:0.51060
# [278]#011train-auc:0.93139#011validation-auc:0.51004
# [279]#011train-auc:0.93163#011validation-auc:0.51029
# [280]#011train-auc:0.93175#011validation-auc:0.50979
# [281]#011train-auc:0.93185#011validation-auc:0.50975
# [282]#011train-auc:0.93196#011validation-auc:0.51006
# [283]#011train-auc:0.93206#011validation-auc:0.51084
# [284]#011train-auc:0.93212#011validation-auc:0.51078
# [285]#011train-auc:0.93223#011validation-auc:0.51069
# [286]#011train-auc:0.93241#011validation-auc:0.51054
# [287]#011train-auc:0.93263#011validation-auc:0.51092
# [288]#011train-auc:0.93279#011validation-auc:0.51066
# [289]#011train-auc:0.93293#011validation-auc:0.51043
# [290]#011train-auc:0.93301#011validation-auc:0.51051
# [291]#011train-auc:0.93322#011validation-auc:0.50996
# [292]#011train-auc:0.93330#011validation-auc:0.50964
# [293]#011train-auc:0.93343#011validation-auc:0.50940
# [294]#011train-auc:0.93363#011validation-auc:0.50999
# [295]#011train-auc:0.93373#011validation-auc:0.51035
# [296]#011train-auc:0.93388#011validation-auc:0.51136
# [297]#011train-auc:0.93407#011validation-auc:0.51066
# [298]#011train-auc:0.93422#011validation-auc:0.51064
# [299]#011train-auc:0.93430#011validation-auc:0.51069
#
# 2026-04-11 19:45:40 Uploading - Uploading generated training model
# 2026-04-11 19:45:40 Completed - Training job completed
# Training seconds: 105
# Billable seconds: 105

# %%
#run hyperparameter tuning through Sagemaker
hyperparameter_ranges = {
    "max_depth": IntegerParameter(3, 8),
    "eta": ContinuousParameter(0.01, 0.3),
    "subsample": ContinuousParameter(0.5, 1.0),
    "colsample_bytree": ContinuousParameter(0.5, 1.0),
    "min_child_weight": IntegerParameter(1, 10),
    "gamma": ContinuousParameter(0.0, 5.0),
    "alpha": ContinuousParameter(0.0, 5.0),
    "lambda": ContinuousParameter(0.0, 5.0),
    "num_round": IntegerParameter(100, 500),
}

tuner = HyperparameterTuner(
    estimator=xgb_estimator,
    objective_metric_name="validation:auc",
    hyperparameter_ranges=hyperparameter_ranges,
    objective_type="Maximize",
    max_jobs=12,
    max_parallel_jobs=3,
    strategy="Bayesian"
)

# %%
# run tuning 
tuner.fit({
    "train": train_input,
    "validation": validation_input
}, wait=True)
# Out:
# INFO:sagemaker:Creating hyperparameter tuning job with name: sagemaker-xgboost-260411-1950
# .................................................................!

# %%
# get the best training job and best estimators
best_job_name = tuner.best_training_job()
print("Best training job:", best_job_name)

best_estimator = tuner.best_estimator()
print("Best estimator model data:", best_estimator.model_data)
# Out:
# Best training job: sagemaker-xgboost-260411-1950-005-3e615797
#
# 2026-04-11 19:53:42 Starting - Found matching resource for reuse
# 2026-04-11 19:53:42 Downloading - Downloading the training image
# 2026-04-11 19:53:42 Training - Training image download completed. Training in progress.
# 2026-04-11 19:53:42 Uploading - Uploading generated training model
# 2026-04-11 19:53:42 Completed - Resource reused by training job: sagemaker-xgboost-260411-1950-008-a87b3313
# Best estimator model data: s3://ads508-team-4-private/model-artifacts/sagemaker-xgboost-260411-1950-005-3e615797/output/model.tar.gz
