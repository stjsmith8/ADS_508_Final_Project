# %% [markdown]
# 05 — Model Training
# TalentIQ Technologies | ADS508 Data Science with Cloud Computing
# Authors: Ramin Fazli & Stephanie Smith
# GitHub: https://github.com/raminfazlirf/MLOps-for-Data-Science-ADS-508-02-
# Team Repo: https://github.com/stjsmith8/ADS_508_Final_Project
#
# Prepared data source: https://github.com/stjsmith8/ADS_508_Final_Project/tree/main/data/processed

# %%
import boto3
import sagemaker
import pandas as pd
import numpy as np

from sagemaker import image_uris
from sagemaker.inputs import TrainingInput
from sagemaker.estimator import Estimator
from sagemaker.tuner import HyperparameterTuner, IntegerParameter, ContinuousParameter

session = sagemaker.Session()
role = sagemaker.get_execution_role()
region = session.boto_region_name
bucket = "ads508-team-4-private"

print("Region:", region)
print("Role:", role)
# Out:
# Region: us-east-1
# Role: arn:aws:iam::802896854792:role/LabRole

# %%
# load datasets from S3 bucket
train_path = f"s3://{bucket}/processed/train_attrition_original.csv"
val_path   = f"s3://{bucket}/processed/validation_attrition_data.csv"
test_path  = f"s3://{bucket}/processed/test_attrition_data.csv"

train_df = pd.read_csv(train_path)
val_df   = pd.read_csv(val_path)
test_df  = pd.read_csv(test_path)

print("Train shape:", train_df.shape)
print("Validation shape:", val_df.shape)
print("Test shape:", test_df.shape)

print(train_df.head())
# Out:
# Train shape: (9176, 28)
# Validation shape: (1147, 28)
# Test shape: (1147, 28)
#    Age  DistanceFromHome  JobInvolvement  JobLevel  JobSatisfaction  \
# 0   54                16               1         3                3
# 1   20                21               3         3                2
# 2   30                 8               2         1                4
# 3   33                 7               3         2                1
# 4   40                11               3         2                1
#
#    EnvironmentSatisfaction  RelationshipSatisfaction  WorkLifeBalance  \
# 0                        3                         3                4
# 1                        1                         3                3
# 2                        3                         3                2
# 3                        4                         1                3
# 4                        1                         1                4
#
#    MonthlyIncome  NumCompaniesWorked  ...    salary_gap  OverTime_Yes  \
# 0          12480                   4  ...  56567.728947             0
# 1          15402                   1  ...  53645.728947             0
# 2           2180                   6  ...  59665.109845             0
# 3           4373                   0  ...  87310.754386             0
# 4          12441                   4  ...  90556.714045             0
#
#    MaritalStatus_Single  MaritalStatus_Married  IncomeCategory_Medium  \
# 0                     0                      0                      1
# 1                     1                      0                      0
# 2                     0                      0                      0
# 3                     0                      1                      0
# 4                     1                      0                      1
#
#    IncomeCategory_High  TenureCategory_3-5 years  TenureCategory_6-10 years  \
# 0                    0                         0                          1
# 1                    1                         0                          0
# 2                    0                         1                          0
# 3                    0                         1                          0
# 4                    0                         0                          0
#
#    TenureCategory_10+ years  Attrition
# 0                         0          1
# 1                         1          1
# 2                         0          1
# 3                         0          0
# 4                         1          0
#
# [5 rows x 28 columns]

# %%
# create scale weight for rebalancing
scale_pos_weight = (train_df["Attrition"] == 0).sum() / (train_df["Attrition"] == 1).sum()
print("scale_pos_weight:", scale_pos_weight)
# Out:
# scale_pos_weight: 4.134862898712926

# %%
# ensure we only keep wanted features
selected_features = [
    "OverTime_Yes",
    "JobInvolvement",
    "WorkLifeBalance",
    "StagnationScore",
    "NoRecentPromotion",
    "SatisfactionIndex",
    "salary_gap",
    "external_job_demand",
    "TenureCategory_3-5 years",
    "TenureCategory_6-10 years",
    "TenureCategory_10+ years",
    "IncomeCategory_Medium",
    "IncomeCategory_High",
]

selected_features = [c for c in selected_features if c in train_df.columns]

target_col = "Attrition"

train_df = train_df[[target_col] + selected_features]
val_df   = val_df[[target_col] + selected_features]
test_df  = test_df[[target_col] + selected_features]

print("Final feature count:", len(selected_features))
print("Training columns:", train_df.columns.tolist())
# Out:
# Final feature count: 13
# Training columns: ['Attrition', 'OverTime_Yes', 'JobInvolvement', 'WorkLifeBalance', 'StagnationScore', 'NoRecentPromotion', 'SatisfactionIndex', 'salary_gap', 'external_job_demand', 'TenureCategory_3-5 years', 'TenureCategory_6-10 years', 'TenureCategory_10+ years', 'IncomeCategory_Medium', 'IncomeCategory_High']

# %%
# update format so we can use Sagemaker built in XGboost
train_xgb_local = "/tmp/train_xgb.csv"
val_xgb_local   = "/tmp/validation_xgb.csv"
test_xgb_local  = "/tmp/test_xgb.csv"

train_df.to_csv(train_xgb_local, index=False, header=False)
val_df.to_csv(val_xgb_local, index=False, header=False)
test_df.to_csv(test_xgb_local, index=False, header=False)

print("Saved local built-in XGBoost files.")
# Out:
# Saved local built-in XGBoost files.

# %%
#upload to S3
train_xgb_s3 = f"s3://{bucket}/processed_builtin/train/train_xgb.csv"
val_xgb_s3   = f"s3://{bucket}/processed_builtin/validation/validation_xgb.csv"
test_xgb_s3  = f"s3://{bucket}/processed_builtin/test/test_xgb.csv"

session.upload_data(train_xgb_local, bucket=bucket, key_prefix="processed_builtin/train")
session.upload_data(val_xgb_local, bucket=bucket, key_prefix="processed_builtin/validation")
session.upload_data(test_xgb_local, bucket=bucket, key_prefix="processed_builtin/test")

print(train_xgb_s3)
print(val_xgb_s3)
print(test_xgb_s3)
# Out:
# s3://ads508-team-4-private/processed_builtin/train/train_xgb.csv
# s3://ads508-team-4-private/processed_builtin/validation/validation_xgb.csv
# s3://ads508-team-4-private/processed_builtin/test/test_xgb.csv

# %%
# get built in xgboost container
xgb_image = image_uris.retrieve(
    framework="xgboost",
    region=region,
    version="1.7-1"
)

print("XGBoost image:", xgb_image)
# Out:
# INFO:sagemaker.image_uris:Ignoring unnecessary instance type: None.
# XGBoost image: 683313688378.dkr.ecr.us-east-1.amazonaws.com/sagemaker-xgboost:1.7-1

# %%
# create Sagemaker training job
xgb_estimator = Estimator(
    image_uri=xgb_image,
    role=role,
    instance_count=1,
    instance_type="ml.m5.xlarge",
    output_path=f"s3://{bucket}/model-artifacts/",
    sagemaker_session=session
)

xgb_estimator.set_hyperparameters(
    objective="binary:logistic",
    eval_metric="auc",
    num_round=300,
    max_depth=4,
    eta=0.05,
    subsample=0.8,
    colsample_bytree=0.8,
    min_child_weight=3,
    gamma=0.05,
    alpha=0.1,
    scale_pos_weight=scale_pos_weight,
    **{"lambda": 1.0}
)

train_input = TrainingInput(
    s3_data=f"s3://{bucket}/processed_builtin/train/",
    content_type="text/csv"
)

validation_input = TrainingInput(
    s3_data=f"s3://{bucket}/processed_builtin/validation/",
    content_type="text/csv"
)

xgb_estimator.fit({
    "train": train_input,
    "validation": validation_input
})
# Out:
# INFO:sagemaker.telemetry.telemetry_logging:SageMaker Python SDK will collect telemetry to help us better understand our user's needs, diagnose issues, and deliver additional features.
# To opt out of telemetry, please disable via TelemetryOptOut parameter in SDK defaults config. For more information, refer to https://sagemaker.readthedocs.io/en/stable/overview.html#configuring-and-using-defaults-with-the-sagemaker-python-sdk.
# INFO:sagemaker:Creating training-job with name: sagemaker-xgboost-2026-04-11-20-53-40-848
# 2026-04-11 20:53:43 Starting - Starting the training job...
# 2026-04-11 20:53:57 Starting - Preparing the instances for training...
# 2026-04-11 20:54:46 Downloading - Downloading the training image......
# 2026-04-11 20:55:37 Training - Training image download completed. Training in progress../miniconda3/lib/python3.9/site-packages/sagemaker_containers/_server.py:22: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# [2026-04-11 20:55:47.901 ip-10-2-92-66.ec2.internal:7 INFO utils.py:28] RULE_JOB_STOP_SIGNAL_FILENAME: None
# [2026-04-11 20:55:47.975 ip-10-2-92-66.ec2.internal:7 INFO profiler_config_parser.py:111] User has disabled profiler.
# [2026-04-11:20:55:48:INFO] Imported framework sagemaker_xgboost_container.training
# [2026-04-11:20:55:48:INFO] Failed to parse hyperparameter eval_metric value auc to Json.
# Returning the value itself
# [2026-04-11:20:55:48:INFO] Failed to parse hyperparameter objective value binary:logistic to Json.
# Returning the value itself
# [2026-04-11:20:55:48:INFO] No GPUs detected (normal if no gpus installed)
# [2026-04-11:20:55:48:INFO] Running XGBoost Sagemaker in algorithm mode
# [2026-04-11:20:55:48:INFO] Determined 0 GPU(s) available on the instance.
# [2026-04-11:20:55:48:INFO] Determined delimiter of CSV input is ','
# [2026-04-11:20:55:48:INFO] Determined delimiter of CSV input is ','
# [2026-04-11:20:55:48:INFO] File path /opt/ml/input/data/train of input files
# [2026-04-11:20:55:48:INFO] Making smlinks from folder /opt/ml/input/data/train to folder /tmp/sagemaker_xgboost_input_data
# [2026-04-11:20:55:48:INFO] creating symlink between Path /opt/ml/input/data/train/train_xgb.csv and destination /tmp/sagemaker_xgboost_input_data/train_xgb.csv-8533397184595548563
# [2026-04-11:20:55:48:INFO] files path: /tmp/sagemaker_xgboost_input_data
# [2026-04-11:20:55:48:INFO] Determined delimiter of CSV input is ','
# [2026-04-11:20:55:48:INFO] File path /opt/ml/input/data/validation of input files
# [2026-04-11:20:55:48:INFO] Making smlinks from folder /opt/ml/input/data/validation to folder /tmp/sagemaker_xgboost_input_data
# [2026-04-11:20:55:48:INFO] creating symlink between Path /opt/ml/input/data/validation/validation_xgb.csv and destination /tmp/sagemaker_xgboost_input_data/validation_xgb.csv5664286832178324896
# [2026-04-11:20:55:48:INFO] files path: /tmp/sagemaker_xgboost_input_data
# [2026-04-11:20:55:48:INFO] Determined delimiter of CSV input is ','
# [2026-04-11:20:55:48:INFO] Single node training.
# [2026-04-11:20:55:48:INFO] Train matrix has 9176 rows and 13 columns
# [2026-04-11:20:55:48:INFO] Validation matrix has 1147 rows
# [2026-04-11 20:55:48.361 ip-10-2-92-66.ec2.internal:7 INFO json_config.py:92] Creating hook from json_config at /opt/ml/input/config/debughookconfig.json.
# [2026-04-11 20:55:48.362 ip-10-2-92-66.ec2.internal:7 INFO hook.py:206] tensorboard_dir has not been set for the hook. SMDebug will not be exporting tensorboard summaries.
# [2026-04-11 20:55:48.362 ip-10-2-92-66.ec2.internal:7 INFO hook.py:259] Saving to /opt/ml/output/tensors
# [2026-04-11 20:55:48.363 ip-10-2-92-66.ec2.internal:7 INFO state_store.py:77] The checkpoint config file /opt/ml/input/config/checkpointconfig.json does not exist.
# [2026-04-11:20:55:48:INFO] Debug hook created from config
# [2026-04-11 20:55:48.395 ip-10-2-92-66.ec2.internal:7 INFO hook.py:427] Monitoring the collections: metrics
# [2026-04-11 20:55:48.400 ip-10-2-92-66.ec2.internal:7 INFO hook.py:491] Hook is writing from the hook with pid: 7
# [0]#011train-auc:0.57023#011validation-auc:0.53558
# [1]#011train-auc:0.58044#011validation-auc:0.53843
# [2]#011train-auc:0.59139#011validation-auc:0.53938
# [3]#011train-auc:0.60068#011validation-auc:0.55730
# [4]#011train-auc:0.61149#011validation-auc:0.56137
# [5]#011train-auc:0.61203#011validation-auc:0.56449
# [6]#011train-auc:0.61254#011validation-auc:0.56583
# [7]#011train-auc:0.61354#011validation-auc:0.57189
# [8]#011train-auc:0.61536#011validation-auc:0.57345
# [9]#011train-auc:0.61531#011validation-auc:0.56838
# [10]#011train-auc:0.61417#011validation-auc:0.56534
# [11]#011train-auc:0.61981#011validation-auc:0.56805
# [12]#011train-auc:0.62249#011validation-auc:0.56759
# [13]#011train-auc:0.62475#011validation-auc:0.55903
# [14]#011train-auc:0.62482#011validation-auc:0.55930
# [15]#011train-auc:0.62511#011validation-auc:0.55841
# [16]#011train-auc:0.62704#011validation-auc:0.55565
# [17]#011train-auc:0.62621#011validation-auc:0.55614
# [18]#011train-auc:0.62631#011validation-auc:0.55685
# [19]#011train-auc:0.62611#011validation-auc:0.55721
# [20]#011train-auc:0.62788#011validation-auc:0.55467
# [21]#011train-auc:0.62955#011validation-auc:0.55520
# [22]#011train-auc:0.63123#011validation-auc:0.55268
# [23]#011train-auc:0.63238#011validation-auc:0.55212
# [24]#011train-auc:0.63294#011validation-auc:0.55027
# [25]#011train-auc:0.63630#011validation-auc:0.55291
# [26]#011train-auc:0.63613#011validation-auc:0.54991
# [27]#011train-auc:0.63810#011validation-auc:0.54703
# [28]#011train-auc:0.63821#011validation-auc:0.54682
# [29]#011train-auc:0.64010#011validation-auc:0.54688
# [30]#011train-auc:0.64040#011validation-auc:0.54665
# [31]#011train-auc:0.64145#011validation-auc:0.54847
# [32]#011train-auc:0.64206#011validation-auc:0.54820
# [33]#011train-auc:0.64384#011validation-auc:0.54713
# [34]#011train-auc:0.64532#011validation-auc:0.54423
# [35]#011train-auc:0.64763#011validation-auc:0.54710
# [36]#011train-auc:0.64904#011validation-auc:0.54529
# [37]#011train-auc:0.65081#011validation-auc:0.54402
# [38]#011train-auc:0.65160#011validation-auc:0.54501
# [39]#011train-auc:0.65308#011validation-auc:0.54776
# [40]#011train-auc:0.65466#011validation-auc:0.54759
# [41]#011train-auc:0.65601#011validation-auc:0.54582
# [42]#011train-auc:0.65845#011validation-auc:0.54868
# [43]#011train-auc:0.66079#011validation-auc:0.54806
# [44]#011train-auc:0.66259#011validation-auc:0.54779
# [45]#011train-auc:0.66344#011validation-auc:0.54883
# [46]#011train-auc:0.66407#011validation-auc:0.54801
# [47]#011train-auc:0.66562#011validation-auc:0.54793
# [48]#011train-auc:0.66526#011validation-auc:0.54740
# [49]#011train-auc:0.66612#011validation-auc:0.54756
# [50]#011train-auc:0.66744#011validation-auc:0.54641
# [51]#011train-auc:0.66813#011validation-auc:0.54768
# [52]#011train-auc:0.66813#011validation-auc:0.54781
# [53]#011train-auc:0.66751#011validation-auc:0.54717
# [54]#011train-auc:0.66779#011validation-auc:0.54608
# [55]#011train-auc:0.66872#011validation-auc:0.54507
# [56]#011train-auc:0.66943#011validation-auc:0.54480
# [57]#011train-auc:0.67034#011validation-auc:0.54336
# [58]#011train-auc:0.67147#011validation-auc:0.54220
# [59]#011train-auc:0.67308#011validation-auc:0.54305
# [60]#011train-auc:0.67407#011validation-auc:0.54434
# [61]#011train-auc:0.67600#011validation-auc:0.54460
# [62]#011train-auc:0.67638#011validation-auc:0.54382
# [63]#011train-auc:0.67737#011validation-auc:0.54491
# [64]#011train-auc:0.67757#011validation-auc:0.54598
# [65]#011train-auc:0.68054#011validation-auc:0.54260
# [66]#011train-auc:0.68067#011validation-auc:0.54198
# [67]#011train-auc:0.68120#011validation-auc:0.54278
# [68]#011train-auc:0.68242#011validation-auc:0.54150
# [69]#011train-auc:0.68268#011validation-auc:0.54068
# [70]#011train-auc:0.68259#011validation-auc:0.54051
# [71]#011train-auc:0.68275#011validation-auc:0.54123
# [72]#011train-auc:0.68299#011validation-auc:0.54030
# [73]#011train-auc:0.68382#011validation-auc:0.53899
# [74]#011train-auc:0.68549#011validation-auc:0.53778
# [75]#011train-auc:0.68718#011validation-auc:0.53842
# [76]#011train-auc:0.68751#011validation-auc:0.53952
# [77]#011train-auc:0.68748#011validation-auc:0.53979
# [78]#011train-auc:0.68810#011validation-auc:0.54018
# [79]#011train-auc:0.68822#011validation-auc:0.54014
# [80]#011train-auc:0.68954#011validation-auc:0.53915
# [81]#011train-auc:0.69026#011validation-auc:0.53720
# [82]#011train-auc:0.69043#011validation-auc:0.53662
# [83]#011train-auc:0.69113#011validation-auc:0.53789
# [84]#011train-auc:0.69193#011validation-auc:0.53910
# [85]#011train-auc:0.69334#011validation-auc:0.53786
# [86]#011train-auc:0.69280#011validation-auc:0.53707
# [87]#011train-auc:0.69385#011validation-auc:0.53756
# [88]#011train-auc:0.69450#011validation-auc:0.53735
# [89]#011train-auc:0.69514#011validation-auc:0.53578
# [90]#011train-auc:0.69619#011validation-auc:0.53588
# [91]#011train-auc:0.69672#011validation-auc:0.53668
# [92]#011train-auc:0.69753#011validation-auc:0.53587
# [93]#011train-auc:0.69857#011validation-auc:0.53569
# [94]#011train-auc:0.69897#011validation-auc:0.53682
# [95]#011train-auc:0.70003#011validation-auc:0.53553
# [96]#011train-auc:0.70249#011validation-auc:0.53592
# [97]#011train-auc:0.70283#011validation-auc:0.53605
# [98]#011train-auc:0.70337#011validation-auc:0.53531
# [99]#011train-auc:0.70374#011validation-auc:0.53657
# [100]#011train-auc:0.70487#011validation-auc:0.53774
# [101]#011train-auc:0.70573#011validation-auc:0.53777
# [102]#011train-auc:0.70636#011validation-auc:0.53801
# [103]#011train-auc:0.70652#011validation-auc:0.53678
# [104]#011train-auc:0.70666#011validation-auc:0.53952
# [105]#011train-auc:0.70668#011validation-auc:0.53903
# [106]#011train-auc:0.70721#011validation-auc:0.53912
# [107]#011train-auc:0.70752#011validation-auc:0.53867
# [108]#011train-auc:0.70912#011validation-auc:0.53836
# [109]#011train-auc:0.71050#011validation-auc:0.53893
# [110]#011train-auc:0.71153#011validation-auc:0.53957
# [111]#011train-auc:0.71276#011validation-auc:0.53864
# [112]#011train-auc:0.71332#011validation-auc:0.53806
# [113]#011train-auc:0.71360#011validation-auc:0.53789
# [114]#011train-auc:0.71420#011validation-auc:0.53726
# [115]#011train-auc:0.71591#011validation-auc:0.53779
# [116]#011train-auc:0.71704#011validation-auc:0.53908
# [117]#011train-auc:0.71738#011validation-auc:0.53985
# [118]#011train-auc:0.71831#011validation-auc:0.53856
# [119]#011train-auc:0.71786#011validation-auc:0.53851
# [120]#011train-auc:0.71852#011validation-auc:0.53779
# [121]#011train-auc:0.71951#011validation-auc:0.53721
# [122]#011train-auc:0.71981#011validation-auc:0.53666
# [123]#011train-auc:0.72014#011validation-auc:0.53727
# [124]#011train-auc:0.72061#011validation-auc:0.53649
# [125]#011train-auc:0.72145#011validation-auc:0.53578
# [126]#011train-auc:0.72206#011validation-auc:0.53590
# [127]#011train-auc:0.72214#011validation-auc:0.53705
# [128]#011train-auc:0.72221#011validation-auc:0.53629
# [129]#011train-auc:0.72273#011validation-auc:0.53647
# [130]#011train-auc:0.72348#011validation-auc:0.53658
# [131]#011train-auc:0.72323#011validation-auc:0.53648
# [132]#011train-auc:0.72402#011validation-auc:0.53603
# [133]#011train-auc:0.72501#011validation-auc:0.53671
# [134]#011train-auc:0.72559#011validation-auc:0.53704
# [135]#011train-auc:0.72744#011validation-auc:0.53837
# [136]#011train-auc:0.72865#011validation-auc:0.53851
# [137]#011train-auc:0.72879#011validation-auc:0.53812
# [138]#011train-auc:0.72964#011validation-auc:0.53929
# [139]#011train-auc:0.73060#011validation-auc:0.53935
# [140]#011train-auc:0.73160#011validation-auc:0.54016
# [141]#011train-auc:0.73201#011validation-auc:0.54040
# [142]#011train-auc:0.73308#011validation-auc:0.53986
# [143]#011train-auc:0.73437#011validation-auc:0.54119
# [144]#011train-auc:0.73515#011validation-auc:0.53969
# [145]#011train-auc:0.73593#011validation-auc:0.54074
# [146]#011train-auc:0.73663#011validation-auc:0.54124
# [147]#011train-auc:0.73750#011validation-auc:0.54247
# [148]#011train-auc:0.73833#011validation-auc:0.54215
# [149]#011train-auc:0.73920#011validation-auc:0.54157
# [150]#011train-auc:0.73936#011validation-auc:0.54157
# [151]#011train-auc:0.74009#011validation-auc:0.54204
# [152]#011train-auc:0.74026#011validation-auc:0.54135
# [153]#011train-auc:0.74073#011validation-auc:0.54158
# [154]#011train-auc:0.74144#011validation-auc:0.54096
# [155]#011train-auc:0.74180#011validation-auc:0.54125
# [156]#011train-auc:0.74244#011validation-auc:0.54171
# [157]#011train-auc:0.74308#011validation-auc:0.54220
# [158]#011train-auc:0.74404#011validation-auc:0.54096
# [159]#011train-auc:0.74474#011validation-auc:0.54028
# [160]#011train-auc:0.74582#011validation-auc:0.54048
# [161]#011train-auc:0.74655#011validation-auc:0.53926
# [162]#011train-auc:0.74690#011validation-auc:0.54006
# [163]#011train-auc:0.74782#011validation-auc:0.54054
# [164]#011train-auc:0.74812#011validation-auc:0.54069
# [165]#011train-auc:0.74843#011validation-auc:0.53996
# [166]#011train-auc:0.74923#011validation-auc:0.54032
# [167]#011train-auc:0.74923#011validation-auc:0.54017
# [168]#011train-auc:0.74945#011validation-auc:0.53940
# [169]#011train-auc:0.74966#011validation-auc:0.53974
# [170]#011train-auc:0.74989#011validation-auc:0.53989
# [171]#011train-auc:0.75031#011validation-auc:0.54014
# [172]#011train-auc:0.75044#011validation-auc:0.53948
# [173]#011train-auc:0.75149#011validation-auc:0.53866
# [174]#011train-auc:0.75256#011validation-auc:0.53970
# [175]#011train-auc:0.75341#011validation-auc:0.53898
# [176]#011train-auc:0.75351#011validation-auc:0.53890
# [177]#011train-auc:0.75430#011validation-auc:0.53970
# [178]#011train-auc:0.75451#011validation-auc:0.53946
# [179]#011train-auc:0.75456#011validation-auc:0.53839
# [180]#011train-auc:0.75447#011validation-auc:0.53789
# [181]#011train-auc:0.75517#011validation-auc:0.53752
# [182]#011train-auc:0.75578#011validation-auc:0.53659
# [183]#011train-auc:0.75574#011validation-auc:0.53755
# [184]#011train-auc:0.75662#011validation-auc:0.53658
# [185]#011train-auc:0.75726#011validation-auc:0.53533
# [186]#011train-auc:0.75719#011validation-auc:0.53551
# [187]#011train-auc:0.75768#011validation-auc:0.53457
# [188]#011train-auc:0.75854#011validation-auc:0.53312
# [189]#011train-auc:0.76013#011validation-auc:0.53329
# [190]#011train-auc:0.76102#011validation-auc:0.53278
# [191]#011train-auc:0.76186#011validation-auc:0.53209
# [192]#011train-auc:0.76204#011validation-auc:0.53185
# [193]#011train-auc:0.76228#011validation-auc:0.53219
# [194]#011train-auc:0.76251#011validation-auc:0.53112
# [195]#011train-auc:0.76254#011validation-auc:0.53079
# [196]#011train-auc:0.76310#011validation-auc:0.53037
# [197]#011train-auc:0.76390#011validation-auc:0.53155
# [198]#011train-auc:0.76442#011validation-auc:0.53082
# [199]#011train-auc:0.76516#011validation-auc:0.53093
# [200]#011train-auc:0.76571#011validation-auc:0.53069
# [201]#011train-auc:0.76607#011validation-auc:0.53121
# [202]#011train-auc:0.76621#011validation-auc:0.53120
# [203]#011train-auc:0.76636#011validation-auc:0.53156
# [204]#011train-auc:0.76657#011validation-auc:0.53169
# [205]#011train-auc:0.76690#011validation-auc:0.53130
# [206]#011train-auc:0.76698#011validation-auc:0.53139
# [207]#011train-auc:0.76732#011validation-auc:0.53160
# [208]#011train-auc:0.76842#011validation-auc:0.53086
# [209]#011train-auc:0.76902#011validation-auc:0.53062
# [210]#011train-auc:0.76917#011validation-auc:0.53066
# [211]#011train-auc:0.76952#011validation-auc:0.53046
# [212]#011train-auc:0.77013#011validation-auc:0.53030
# [213]#011train-auc:0.77061#011validation-auc:0.52984
# [214]#011train-auc:0.77038#011validation-auc:0.52994
# [215]#011train-auc:0.77068#011validation-auc:0.53083
# [216]#011train-auc:0.77086#011validation-auc:0.52965
# [217]#011train-auc:0.77163#011validation-auc:0.52981
# [218]#011train-auc:0.77206#011validation-auc:0.52986
# [219]#011train-auc:0.77253#011validation-auc:0.52987
# [220]#011train-auc:0.77327#011validation-auc:0.53035
# [221]#011train-auc:0.77358#011validation-auc:0.53097
# [222]#011train-auc:0.77374#011validation-auc:0.53152
# [223]#011train-auc:0.77415#011validation-auc:0.53088
# [224]#011train-auc:0.77443#011validation-auc:0.53080
# [225]#011train-auc:0.77553#011validation-auc:0.53092
# [226]#011train-auc:0.77600#011validation-auc:0.53003
# [227]#011train-auc:0.77648#011validation-auc:0.53008
# [228]#011train-auc:0.77703#011validation-auc:0.53008
# [229]#011train-auc:0.77755#011validation-auc:0.53036
# [230]#011train-auc:0.77793#011validation-auc:0.53075
# [231]#011train-auc:0.77832#011validation-auc:0.53116
# [232]#011train-auc:0.77835#011validation-auc:0.53085
# [233]#011train-auc:0.77874#011validation-auc:0.53142
# [234]#011train-auc:0.77892#011validation-auc:0.53146
# [235]#011train-auc:0.77921#011validation-auc:0.53108
# [236]#011train-auc:0.77932#011validation-auc:0.53111
# [237]#011train-auc:0.78004#011validation-auc:0.53002
# [238]#011train-auc:0.78025#011validation-auc:0.52994
# [239]#011train-auc:0.78051#011validation-auc:0.52986
# [240]#011train-auc:0.78107#011validation-auc:0.53051
# [241]#011train-auc:0.78133#011validation-auc:0.53092
# [242]#011train-auc:0.78201#011validation-auc:0.53052
# [243]#011train-auc:0.78222#011validation-auc:0.53106
# [244]#011train-auc:0.78273#011validation-auc:0.53043
# [245]#011train-auc:0.78298#011validation-auc:0.53031
# [246]#011train-auc:0.78356#011validation-auc:0.53015
# [247]#011train-auc:0.78451#011validation-auc:0.53060
# [248]#011train-auc:0.78486#011validation-auc:0.53104
# [249]#011train-auc:0.78528#011validation-auc:0.53147
# [250]#011train-auc:0.78568#011validation-auc:0.53195
# [251]#011train-auc:0.78610#011validation-auc:0.53150
# [252]#011train-auc:0.78627#011validation-auc:0.53172
# [253]#011train-auc:0.78658#011validation-auc:0.53210
# [254]#011train-auc:0.78678#011validation-auc:0.53224
# [255]#011train-auc:0.78678#011validation-auc:0.53335
# [256]#011train-auc:0.78694#011validation-auc:0.53335
# [257]#011train-auc:0.78765#011validation-auc:0.53339
# [258]#011train-auc:0.78780#011validation-auc:0.53267
# [259]#011train-auc:0.78823#011validation-auc:0.53237
# [260]#011train-auc:0.78833#011validation-auc:0.53196
# [261]#011train-auc:0.78852#011validation-auc:0.53165
# [262]#011train-auc:0.78904#011validation-auc:0.53199
# [263]#011train-auc:0.78931#011validation-auc:0.53226
# [264]#011train-auc:0.78971#011validation-auc:0.53346
# [265]#011train-auc:0.79023#011validation-auc:0.53391
# [266]#011train-auc:0.79069#011validation-auc:0.53459
# [267]#011train-auc:0.79135#011validation-auc:0.53422
# [268]#011train-auc:0.79171#011validation-auc:0.53392
# [269]#011train-auc:0.79168#011validation-auc:0.53412
# [270]#011train-auc:0.79222#011validation-auc:0.53400
# [271]#011train-auc:0.79299#011validation-auc:0.53457
# [272]#011train-auc:0.79338#011validation-auc:0.53332
# [273]#011train-auc:0.79401#011validation-auc:0.53258
# [274]#011train-auc:0.79480#011validation-auc:0.53196
# [275]#011train-auc:0.79479#011validation-auc:0.53161
# [276]#011train-auc:0.79485#011validation-auc:0.53121
# [277]#011train-auc:0.79509#011validation-auc:0.53086
# [278]#011train-auc:0.79593#011validation-auc:0.53167
# [279]#011train-auc:0.79634#011validation-auc:0.53185
# [280]#011train-auc:0.79641#011validation-auc:0.53115
# [281]#011train-auc:0.79674#011validation-auc:0.53126
# [282]#011train-auc:0.79662#011validation-auc:0.53093
# [283]#011train-auc:0.79738#011validation-auc:0.53116
# [284]#011train-auc:0.79759#011validation-auc:0.53078
# [285]#011train-auc:0.79833#011validation-auc:0.53039
# [286]#011train-auc:0.79841#011validation-auc:0.53081
# [287]#011train-auc:0.79915#011validation-auc:0.53032
# [288]#011train-auc:0.79966#011validation-auc:0.53051
# [289]#011train-auc:0.79984#011validation-auc:0.53052
# [290]#011train-auc:0.79985#011validation-auc:0.52990
# [291]#011train-auc:0.80003#011validation-auc:0.53015
# [292]#011train-auc:0.80046#011validation-auc:0.52999
# [293]#011train-auc:0.80077#011validation-auc:0.52935
# [294]#011train-auc:0.80093#011validation-auc:0.52918
# [295]#011train-auc:0.80085#011validation-auc:0.52966
# [296]#011train-auc:0.80105#011validation-auc:0.52992
# [297]#011train-auc:0.80129#011validation-auc:0.52968
# [298]#011train-auc:0.80166#011validation-auc:0.53048
# [299]#011train-auc:0.80193#011validation-auc:0.53080
#
# 2026-04-11 20:56:05 Uploading - Uploading generated training model
# 2026-04-11 20:56:05 Completed - Training job completed
# Training seconds: 104
# Billable seconds: 104

# %%
#run hyperparameter tuning through Sagemaker
hyperparameter_ranges = {
    "max_depth": IntegerParameter(3, 8),
    "eta": ContinuousParameter(0.01, 0.3),
    "subsample": ContinuousParameter(0.5, 1.0),
    "colsample_bytree": ContinuousParameter(0.5, 1.0),
    "min_child_weight": IntegerParameter(1, 10),
    "gamma": ContinuousParameter(0.0, 5.0),
    "alpha": ContinuousParameter(0.0, 5.0),
    "lambda": ContinuousParameter(0.0, 5.0),
    "num_round": IntegerParameter(100, 500),
}

tuner = HyperparameterTuner(
    estimator=xgb_estimator,
    objective_metric_name="validation:auc",
    hyperparameter_ranges=hyperparameter_ranges,
    objective_type="Maximize",
    max_jobs=9,
    max_parallel_jobs=3,
    strategy="Bayesian"
)

# %%
# run tuning 
tuner.fit({
    "train": train_input,
    "validation": validation_input
}, wait=True)
# Out:
# INFO:sagemaker:Creating hyperparameter tuning job with name: sagemaker-xgboost-260411-2056
# ......................................................!

# %%
# get the best training job and best estimators
best_job_name = tuner.best_training_job()
print("Best training job:", best_job_name)

best_estimator = tuner.best_estimator()
print("Best estimator model data:", best_estimator.model_data)
# Out:
# Best training job: sagemaker-xgboost-260411-2056-005-38086c4e
#
# 2026-04-11 21:00:27 Starting - Found matching resource for reuse
# 2026-04-11 21:00:27 Downloading - Downloading the training image
# 2026-04-11 21:00:27 Training - Training image download completed. Training in progress.
# 2026-04-11 21:00:27 Uploading - Uploading generated training model
# 2026-04-11 21:00:27 Completed - Resource reused by training job: sagemaker-xgboost-260411-2056-009-5ed79c67
# Best estimator model data: s3://ads508-team-4-private/model-artifacts/sagemaker-xgboost-260411-2056-005-38086c4e/output/model.tar.gz
